# %% [markdown]
# # Fixing errors in the calculations

# %% [markdown]
# When you hand in the homework for this exercise (at least for all problems in this page), you should give the modified code for each question and mark the position where you modified the code. Only the modified part is necessary. Thanks!

# %%
import psi4
import py3Dmol
import pandas as pd

import sys
sys.path.append("..")
from helpers import *

# %%
psi4.set_num_threads(2)
psi4.set_memory('2 GB')
# Out:
# 2000000000

# %% [markdown]
# ## Allyl radical

# %% [markdown]
# :::{admonition} Exercise 1
# :class: exercise
# Fix the error in the single-point wavefunction optimization for the allyl radical using the BLYP exchange-correlation functional.
# :::

# %%
allyl_radical = psi4.geometry("""
symmetry c1
0 2
 C     1.307894    -0.292412     0.050945
 C     0.000000     0.443183     0.200966
 C    -1.307894    -0.292412     0.050945
 H     2.171777     0.390984     0.102354
 H     1.440837    -1.062338     0.844942
 H     1.356754    -0.838161    -0.914887
 H     0.000000     1.488670     0.522326
 H    -2.171777     0.390984     0.102354
 H    -1.356754    -0.838161    -0.914887
 H    -1.440837    -1.062338     0.844942""")

# %%
psi4.core.set_output_file('allyl_radical.log', False)
psi4.set_options({'reference':'uks'})
psi4.energy('blyp/3-21G', molecule=allyl_radical)
# Out:
# -117.74717687506904

# %%
drawXYZ(allyl_radical)
# Out:
# <div id="3dmolviewer_17639703429466312"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17639703429466312" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17639703429466312 = null;
# var warn = document.getElementById("3dmolwarning_17639703429466312");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17639703429466312 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17639703429466312"),{backgroundColor:"white"});
# viewer_17639703429466312.zoomTo();
# 	viewer_17639703429466312.addModel("10\n\n C    0.217111940963    0.047209279022    1.307894000000\n C   -0.518483059037   -0.102811720978    0.000000000000\n C    0.217111940963    0.047209279022   -1.307894000000\n H   -0.466284059037   -0.004199720978    2.171777000000\n H    0.987037940963   -0.746787720978    1.440837000000\n H    0.762860940963    1.013041279022    1.356754000000\n H   -1.563970059037   -0.424171720978    0.000000000000\n H   -0.466284059037   -0.004199720978   -2.171777000000\n H    0.762860940963    1.013041279022   -1.356754000000\n H    0.987037940963   -0.746787720978   -1.440837000000\n","xyz");
# 	viewer_17639703429466312.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17639703429466312.zoomTo();
# viewer_17639703429466312.render();
# });
# </script>

# %% [markdown]
# ## Copper Water complex

# %% [markdown]
# :::{admonition} Exercise 2
# :class: exercise
# Fix the error in the single-point wavefunction optimisation of the $Cu[H_{2}O]^{2+}$ aqua complex (as observed in the gas phase) using the PBE exchange-correlation functional.
# :::

# %%
cu_h2o_2plus = psi4.geometry("""
2 2
 Cu        0.009000        0.015000        0.004000
 O         0.043000        1.451000       -0.430000
 H         0.050000        1.450000       -1.397000
 H        -0.798000        1.844000       -0.158000
""")

# %%
drawXYZ(cu_h2o_2plus)
# Out:
# <div id="3dmolviewer_176397070453102"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_176397070453102" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_176397070453102 = null;
# var warn = document.getElementById("3dmolwarning_176397070453102");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_176397070453102 = $3Dmol.createViewer(document.getElementById("3dmolviewer_176397070453102"),{backgroundColor:"white"});
# viewer_176397070453102.zoomTo();
# 	viewer_176397070453102.addModel("4\n\nCU    0.002818957497   -0.324415438751    0.105226172240\n O    0.036818957497    1.111584561249   -0.328773827760\n H    0.043818957497    1.110584561249   -1.295773827760\n H   -0.804181042503    1.504584561249   -0.056773827760\n","xyz");
# 	viewer_176397070453102.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_176397070453102.zoomTo();
# viewer_176397070453102.render();
# });
# </script>

# %%
psi4.core.clean()
psi4.core.set_global_option('MAXITER', 100)
# Out:
# True

# %%
psi4.core.set_output_file('copper_water.log', False)
psi4.set_options({'reference': 'uks',})
E = psi4.energy('pbe/6-31G', molecule=cu_h2o_2plus)
E
# Out:
# -1715.311090312827

# %% [markdown]
# ##  N2 Geometry optimization
#
# ```{admonition} Exercise 3
# :class: exercise
# Fix the error in the geometry optimisation of $N_2$ using the BP86 exchange-correlation functional.
# ```

# %%
n2 = psi4.geometry("""
0 1
N 0.000 0.000 0.000
N 0.000 0.000 1.098
""")
# Out:
# <div id="3dmolviewer_17639712606723876"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17639712606723876" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17639712606723876 = null;
# var warn = document.getElementById("3dmolwarning_17639712606723876");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17639712606723876 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17639712606723876"),{backgroundColor:"white"});
# viewer_17639712606723876.zoomTo();
# 	viewer_17639712606723876.addModel("2\n\n N    0.000000000000    0.000000000000   -0.549000000000\n N    0.000000000000    0.000000000000    0.549000000000\n","xyz");
# 	viewer_17639712606723876.setStyle({"stick": {}, "sphere": {"scale": 0.1}});
# 	viewer_17639712606723876.zoomTo();
# viewer_17639712606723876.render();
# });
# </script>

# %%
psi4.core.clean()
psi4.core.set_output_file('n2_opt.log', False)
psi4.optimize('BP86/6-31+G*', molecule=n2)
print(n2.save_string_xyz())
# Out:
# 	Denominators (dg)(dq) or (dq)(dq) are very small.
# 	Skipping Hessian update for step 3.
# Optimizer: Optimization complete!
# 0 1
#  N    0.000000000000    0.000000000000   -0.558480503117
#  N    0.000000000000    0.000000000000    0.558480503117

# %% [markdown]
# ## $^3 O$ Single point optimization
#
# ```{admonition} Exercise 4
# :class: exercise
# Fix the error in the single point calculation of  $^3 O$ using the B97-2 exchange-correlation functional.
# ```

# %%
psi4.core.clean()
psi4.core.clean_options()

# %%
o = psi4.geometry("""
0 3
O 0.0 0.0 0.0
""")

# %%
psi4.core.set_output_file('o3_singlept.log', False)
psi4.set_options({'reference':'uks'})
psi4.energy('b97-2/6-31+G*', molecule=o)
# Out:
# -75.03949771117202
